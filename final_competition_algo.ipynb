# %%
import datetime as dt
import time
import random
import logging

from optibook.synchronous_client import Exchange

exchange = Exchange()
exchange.connect()

logging.getLogger('client').setLevel('ERROR')

def delta_limit_breached(volume,side,limit):
    positions = exchange.get_positions()
    position_A = positions['PHILIPS_A']
    position_B = positions['PHILIPS_B']
    if side == 'bid':
        return abs(position_A + position_B + volume) < limit
    elif side == 'ask':
        return abs(position_A + position_B - volume) < limit
    else:
        raise Exception(f'''Invalid side provided: {side}, expecting 'bid' or 'ask'.''')
    
def trade_would_breach_position_limit(instrument_id, volume, side, position_limit=10):
    positions = exchange.get_positions()
    position_instrument = positions[instrument_id]

    if side == 'bid':
        return position_instrument + volume > position_limit
    elif side == 'ask':
        return position_instrument - volume < -position_limit
    else:
        raise Exception(f'''Invalid side provided: {side}, expecting 'bid' or 'ask'.''')


def print_positions_and_pnl():
    positions = exchange.get_positions()
    pnl = exchange.get_pnl()

    print('Positions:')
    for instrument_id in positions:
        print(f'  {instrument_id:10s}: {positions[instrument_id]:4.0f}')

    print(f'\nPnL: {pnl:.2f}')


STOCK_A_ID = 'PHILIPS_A'
STOCK_B_ID = 'PHILIPS_B'

while True:
    print(f'')
    print(f'-----------------------------------------------------------------')
    print(f'TRADE LOOP ITERATION ENTERED AT {str(dt.datetime.now()):18s} UTC.')
    print(f'-----------------------------------------------------------------')

    print_positions_and_pnl()
    print(f'')

    # Flip a coin to select which stock to trade
    # if random.random() > 0.5:
    #     stock_id = STOCK_A_ID
    # else:
    #     stock_id = STOCK_B_ID
    # print(f'Selected stock {stock_id} to trade.')

    # Obtain order book and only trade if there are both bids and offers available on that stock
    
    stock_id = STOCK_A_ID
    
    tradeticks = exchange.poll_new_trade_ticks(stock_id)
    i=0
    avgderA=0
    for t in tradeticks:
        if(i==25):
            break
        elif(i==0):
            i=i+1
            continue
        avgderA=avgderA+(25-i)*(tradeticks[i].price-tradeticks[i-1].price)
        i=i+1
    avgderA=avgderA/5
    
    stock_id = STOCK_B_ID
    
    tradeticks = exchange.poll_new_trade_ticks(stock_id)
    i=0
    avgderB=0
    for t in tradeticks:
        if(i==25):
            break
        elif(i==0):
            i=i+1
            continue
        avgderB=avgderB+(25-i)*(tradeticks[i].price-tradeticks[i-1].price)
        i=i+1
    avgderB=avgderB/5
    
    print(avgderA)
    print(avgderB)
    if(avgderA>0.1):
        stock_id = STOCK_A_ID
        side='bid'
    elif(avgderA<0):
        if random.random() > 0.25:
            side = 'ask'
            stock_id = STOCK_A_ID
        else:
            side = 'bid'
            stock_id = STOCK_B_ID
    elif(avgderB<0):
        stock_id = STOCK_B_ID
        side='ask'
    else:
        stock_id = STOCK_B_ID
        side='bid'
    
    stock_order_book = exchange.get_last_price_book(stock_id)
    if not (stock_order_book and stock_order_book.bids and stock_order_book.asks):
        print(f'Order book for {stock_id} does not have bids or offers. Skipping iteration.')
        continue

    # Obtain best bid and ask prices from order book
    best_bid_price = stock_order_book.bids[0].price
    best_ask_price = stock_order_book.asks[0].price
    print(f'Top level prices for {stock_id}: {best_bid_price:.2f} :: {best_ask_price:.2f}')
    
    # Flip a coin to decide whether to buy or sell
    if side == 'bid':
        price = best_ask_price
    else:
        price = best_bid_price

    # Insert an IOC order to trade the opposing top-level
    volume = 1
    if not delta_limit_breached(volume,side,10):
        time.sleep(30)
        continue
    if not trade_would_breach_position_limit(stock_id, volume, side):
        print(f'''Inserting {side} for {stock_id}: {volume:.0f} lot(s) at price {price:.2f}.''')
        exchange.insert_order(
            instrument_id=stock_id,
            price=price,
            volume=volume,
            side=side,
            order_type='ioc')
    else:
        print(f'''Not inserting {volume:.0f} lot {side} for {stock_id} to avoid position-limit breach.''')

    print(f'\nSleeping for 5 seconds.')
    time.sleep(30)
# Out:
# 2022-01-23 12:07:58,701 [asyncio   ] [MainThread  ] Using selector: EpollSelector
# 2022-01-23 12:07:58,827 [client    ] [Thread-18   ] Forcing a disconnect due to an error: Closing connection because someone else logged in with the same credentials. Only one session may be active at the same time.
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:07:58.822798 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :    1
#   PHILIPS_B :    8
#
# PnL: -55.10
#
# 0.0
# 0.0
# Top level prices for PHILIPS_B: 100.80 :: 101.10
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:08:28.824412 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :    1
#   PHILIPS_B :    8
#
# PnL: -60.10
#
# -1.3199999999999874
# 0.0
# Top level prices for PHILIPS_A: 100.60 :: 101.30
# Inserting ask for PHILIPS_A: 1 lot(s) at price 100.60.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:08:58.866118 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :    0
#   PHILIPS_B :    8
#
# PnL: -57.00
#
# 2.319999999999999
# 1.4200000000000528
# Top level prices for PHILIPS_A: 100.90 :: 101.10
# Inserting bid for PHILIPS_A: 1 lot(s) at price 101.10.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:09:28.888916 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :    1
#   PHILIPS_B :    8
#
# PnL: -61.10
#
# -0.6400000000000233
# -1.420000000000013
# Top level prices for PHILIPS_A: 100.60 :: 101.10
# Inserting ask for PHILIPS_A: 1 lot(s) at price 100.60.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:09:58.930301 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :    0
#   PHILIPS_B :    8
#
# PnL: -63.10
#
# 0.6399999999999721
# -1.7200000000000017
# Top level prices for PHILIPS_A: 100.60 :: 100.80
# Inserting bid for PHILIPS_A: 1 lot(s) at price 100.80.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:10:28.948980 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :    1
#   PHILIPS_B :    8
#
# PnL: -67.10
#
# -1.0000000000000226
# 1.0799999999999983
# Top level prices for PHILIPS_A: 99.70 :: 100.00
# Inserting ask for PHILIPS_A: 1 lot(s) at price 99.70.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:10:58.992990 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :    0
#   PHILIPS_B :    8
#
# PnL: -69.00
#
# 0.18000000000002672
# -0.540000000000029
# Top level prices for PHILIPS_A: 99.80 :: 100.40
# Inserting bid for PHILIPS_A: 1 lot(s) at price 100.40.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:11:29.018734 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :    1
#   PHILIPS_B :    8
#
# PnL: -70.60
#
# -3.5599999999999823
# -0.33999999999998065
# Top level prices for PHILIPS_A: 99.60 :: 99.80
# Inserting ask for PHILIPS_A: 1 lot(s) at price 99.60.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:11:59.043047 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :    0
#   PHILIPS_B :    8
#
# PnL: -69.80
#
# -0.4200000000000387
# 0.0
# Top level prices for PHILIPS_A: 99.70 :: 99.80
# Inserting ask for PHILIPS_A: 1 lot(s) at price 99.70.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:12:29.076846 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -1
#   PHILIPS_B :    8
#
# PnL: -66.20
#
# 1.8400000000000205
# 1.540000000000012
# Top level prices for PHILIPS_A: 100.10 :: 100.60
# Inserting bid for PHILIPS_A: 1 lot(s) at price 100.60.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:12:59.124523 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :    0
#   PHILIPS_B :    8
#
# PnL: -69.90
#
# -4.540000000000015
# 2.842170943040401e-14
# Top level prices for PHILIPS_A: 99.00 :: 99.40
# Inserting ask for PHILIPS_A: 1 lot(s) at price 99.00.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:13:29.150922 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -1
#   PHILIPS_B :    8
#
# PnL: -72.10
#
# 2.8800000000000407
# -0.9600000000000136
# Top level prices for PHILIPS_A: 99.60 :: 99.80
# Inserting bid for PHILIPS_A: 1 lot(s) at price 99.80.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:13:59.195729 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :    0
#   PHILIPS_B :    8
#
# PnL: -73.10
#
# 1.579999999999987
# -0.67999999999995
# Top level prices for PHILIPS_A: 100.40 :: 100.80
# Inserting bid for PHILIPS_A: 1 lot(s) at price 100.80.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:14:29.225360 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :    1
#   PHILIPS_B :    8
#
# PnL: -69.20
#
# -0.36000000000003923
# -0.9199999999999932
# Top level prices for PHILIPS_A: 100.60 :: 101.10
# Inserting ask for PHILIPS_A: 1 lot(s) at price 100.60.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:14:59.269299 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :    0
#   PHILIPS_B :    8
#
# PnL: -61.30
#
# 1.7599999999999738
# -1.3
# Top level prices for PHILIPS_A: 100.90 :: 101.60
# Inserting bid for PHILIPS_A: 1 lot(s) at price 101.60.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:15:29.306277 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :    1
#   PHILIPS_B :    8
#
# PnL: -66.30
#
# -4.380000000000007
# -1.6799999999999984
# Top level prices for PHILIPS_B: 100.80 :: 101.20
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:15:59.314890 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :    1
#   PHILIPS_B :    8
#
# PnL: -65.30
#
# -0.35999999999997956
# -0.6199999999999732
# Top level prices for PHILIPS_A: 100.70 :: 101.00
# Inserting ask for PHILIPS_A: 1 lot(s) at price 100.70.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:16:29.345980 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :    0
#   PHILIPS_B :    8
#
# PnL: -59.00
#
# 3.2200000000000157
# 0.9000000000000142
# Top level prices for PHILIPS_A: 101.20 :: 101.50
# Inserting bid for PHILIPS_A: 1 lot(s) at price 101.50.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:16:59.390296 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :    1
#   PHILIPS_B :    8
#
# PnL: -64.00
#
# -0.9599999999999455
# -1.8599999999999597
# Top level prices for PHILIPS_A: 101.20 :: 101.80
# Inserting ask for PHILIPS_A: 1 lot(s) at price 101.20.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:17:29.414312 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :    0
#   PHILIPS_B :    8
#
# PnL: -68.90
#
# -3.0599999999999907
# -3.5000000000000426
# Top level prices for PHILIPS_A: 100.10 :: 100.40
# Inserting ask for PHILIPS_A: 1 lot(s) at price 100.10.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:17:59.429243 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -1
#   PHILIPS_B :    8
#
# PnL: -76.30
#
# -2.340000000000026
# -2.8800000000000296
# Top level prices for PHILIPS_A: 99.50 :: 99.90
# Inserting ask for PHILIPS_A: 1 lot(s) at price 99.50.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:18:29.449695 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -2
#   PHILIPS_B :    8
#
# PnL: -74.70
#
# 1.9200000000000272
# 0.0
# Top level prices for PHILIPS_A: 99.20 :: 99.90
# Inserting bid for PHILIPS_A: 1 lot(s) at price 99.90.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:18:59.473001 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -1
#   PHILIPS_B :    8
#
# PnL: -73.10
#
# 2.5799999999999925
# 0.4000000000000085
# Top level prices for PHILIPS_A: 100.20 :: 100.60
# Inserting bid for PHILIPS_A: 1 lot(s) at price 100.60.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:19:29.510721 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :    0
#   PHILIPS_B :    8
#
# PnL: -70.60
#
# 0.9799999999999869
# 0.4799999999999727
# Top level prices for PHILIPS_A: 100.40 :: 101.00
# Inserting bid for PHILIPS_A: 1 lot(s) at price 101.00.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:19:59.554367 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :    1
#   PHILIPS_B :    8
#
# PnL: -74.00
#
# -4.639999999999998
# -1.379999999999987
# Top level prices for PHILIPS_A: 99.20 :: 99.90
# Inserting ask for PHILIPS_A: 1 lot(s) at price 99.20.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:20:29.590943 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :    0
#   PHILIPS_B :    8
#
# PnL: -71.60
#
# 4.120000000000019
# 1.4800000000000069
# Top level prices for PHILIPS_A: 100.20 :: 100.40
# Inserting bid for PHILIPS_A: 1 lot(s) at price 100.40.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:20:59.618596 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :    1
#   PHILIPS_B :    8
#
# PnL: -72.50
#
# -0.33999999999999775
# -1.0799999999999756
# Top level prices for PHILIPS_A: 100.20 :: 100.30
# Inserting ask for PHILIPS_A: 1 lot(s) at price 100.20.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:21:29.665117 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :    0
#   PHILIPS_B :    8
#
# PnL: -77.40
#
# -0.4399999999999977
# 0.26000000000000795
# Top level prices for PHILIPS_B: 99.70 :: 100.00
# Inserting bid for PHILIPS_B: 1 lot(s) at price 100.00.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:21:59.709583 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :    0
#   PHILIPS_B :    9
#
# PnL: -69.50
#
# 4.420000000000002
# 3.3000000000000314
# Top level prices for PHILIPS_A: 101.20 :: 101.80
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:22:29.736658 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :    0
#   PHILIPS_B :    9
#
# PnL: -68.60
#
# -5.480000000000038
# -0.9799999999999557
# Top level prices for PHILIPS_A: 100.00 :: 100.50
# Inserting ask for PHILIPS_A: 1 lot(s) at price 100.00.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:22:59.780747 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -1
#   PHILIPS_B :    9
#
# PnL: -75.30
#
# 1.8200000000000216
# -0.7200000000000244
# Top level prices for PHILIPS_A: 100.20 :: 100.50
# Inserting bid for PHILIPS_A: 1 lot(s) at price 100.50.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:23:29.824190 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :    0
#   PHILIPS_B :    9
#
# PnL: -69.10
#
# 0.36000000000003923
# 1.860000000000025
# Top level prices for PHILIPS_A: 100.10 :: 100.70
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:23:59.856488 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :    0
#   PHILIPS_B :    9
#
# PnL: -71.80
#
# 1.7399999999999607
# 0.0
# Top level prices for PHILIPS_A: 100.00 :: 100.60
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:24:29.861777 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :    0
#   PHILIPS_B :    9
#
# PnL: -85.30
#
# -3.3400000000000345
# -2.39999999999998
# Top level prices for PHILIPS_A: 98.50 :: 99.00
# Inserting ask for PHILIPS_A: 1 lot(s) at price 98.50.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:24:59.885122 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -1
#   PHILIPS_B :    9
#
# PnL: -84.90
#
# 2.440000000000006
# -0.4
# Top level prices for PHILIPS_A: 98.40 :: 99.00
# Inserting bid for PHILIPS_A: 1 lot(s) at price 99.00.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:25:29.902801 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :    0
#   PHILIPS_B :    9
#
# PnL: -84.00
#
# 1.4400000000000546
# 3.2200000000000015
# Top level prices for PHILIPS_A: 98.50 :: 99.00
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:25:59.933631 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :    0
#   PHILIPS_B :    9
#
# PnL: -85.80
#
# 0.4599999999999767
# -1.1199999999999988
# Top level prices for PHILIPS_A: 98.90 :: 99.20
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:26:29.945298 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :    0
#   PHILIPS_B :    9
#
# PnL: -84.90
#
# -1.2199999999999875
# 0.2599999999999881
# Top level prices for PHILIPS_A: 99.50 :: 99.80
# Inserting ask for PHILIPS_A: 1 lot(s) at price 99.50.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:26:59.966665 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -1
#   PHILIPS_B :    9
#
# PnL: -90.30
#
# -2.3999999999999546
# -2.27999999999997
# Top level prices for PHILIPS_A: 97.80 :: 98.50
# Inserting ask for PHILIPS_A: 1 lot(s) at price 97.80.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:27:30.006230 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -2
#   PHILIPS_B :    9
#
# PnL: -91.30
#
# 3.3399999999999808
# -0.25999999999999945
# Top level prices for PHILIPS_A: 98.10 :: 98.60
# Inserting bid for PHILIPS_A: 1 lot(s) at price 98.60.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:28:00.037937 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -1
#   PHILIPS_B :    9
#
# PnL: -91.10
#
# 0.0
# 0.0
# Top level prices for PHILIPS_B: 98.60 :: 99.00
# Inserting bid for PHILIPS_B: 1 lot(s) at price 99.00.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:28:30.092345 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -1
#   PHILIPS_B :   10
#
# PnL: -88.30
#
# 1.8599999999999852
# -0.8599999999999625
# Top level prices for PHILIPS_A: 99.20 :: 99.50
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:29:00.117771 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -1
#   PHILIPS_B :   10
#
# PnL: -81.70
#
# -1.6999999999999802
# 2.2799999999999785
# Top level prices for PHILIPS_A: 99.10 :: 99.40
# Inserting ask for PHILIPS_A: 1 lot(s) at price 99.10.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:29:30.153532 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -2
#   PHILIPS_B :   10
#
# PnL: -86.20
#
# 1.2399999999999978
# -1.1400000000000319
# Top level prices for PHILIPS_A: 99.60 :: 100.30
# Inserting bid for PHILIPS_A: 1 lot(s) at price 100.30.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:30:00.174151 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -1
#   PHILIPS_B :   10
#
# PnL: -81.40
#
# -2.3000000000000114
# 0.31999999999998463
# Top level prices for PHILIPS_A: 99.60 :: 99.90
# Inserting ask for PHILIPS_A: 1 lot(s) at price 99.60.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:30:30.211054 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -2
#   PHILIPS_B :   10
#
# PnL: -84.10
#
# -0.160000000000025
# -1.539999999999992
# Top level prices for PHILIPS_A: 99.20 :: 99.80
# Inserting ask for PHILIPS_A: 1 lot(s) at price 99.20.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:31:00.237546 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -3
#   PHILIPS_B :   10
#
# PnL: -85.90
#
# 2.3600000000000194
# 0.12000000000000739
# Top level prices for PHILIPS_A: 98.80 :: 99.40
# Inserting bid for PHILIPS_A: 1 lot(s) at price 99.40.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:31:30.278279 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -2
#   PHILIPS_B :   10
#
# PnL: -88.50
#
# -1.8200000000000216
# -0.840000000000012
# Top level prices for PHILIPS_B: 98.60 :: 98.80
# Not inserting 1 lot bid for PHILIPS_B to avoid position-limit breach.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:32:00.304314 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -2
#   PHILIPS_B :   10
#
# PnL: -89.50
#
# -3.240000000000009
# -0.48000000000004095
# Top level prices for PHILIPS_A: 98.10 :: 98.60
# Inserting ask for PHILIPS_A: 1 lot(s) at price 98.10.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:32:30.318588 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -3
#   PHILIPS_B :   10
#
# PnL: -92.90
#
# 1.7599999999999825
# 0.31999999999997614
# Top level prices for PHILIPS_A: 97.90 :: 98.50
# Inserting bid for PHILIPS_A: 1 lot(s) at price 98.50.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:33:00.353088 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -2
#   PHILIPS_B :   10
#
# PnL: -94.10
#
# -2.3799999999999755
# -0.43999999999997785
# Top level prices for PHILIPS_A: 97.90 :: 98.40
# Inserting ask for PHILIPS_A: 1 lot(s) at price 97.90.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:33:30.397556 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -3
#   PHILIPS_B :   10
#
# PnL: -95.10
#
# 0.0
# -0.28000000000004094
# Top level prices for PHILIPS_B: 98.00 :: 98.20
# Inserting ask for PHILIPS_B: 1 lot(s) at price 98.00.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:34:00.442500 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -3
#   PHILIPS_B :    9
#
# PnL: -94.20
#
# -1.9199999999999988
# 0.9800000000000239
# Top level prices for PHILIPS_B: 97.30 :: 97.70
# Inserting bid for PHILIPS_B: 1 lot(s) at price 97.70.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:34:30.477847 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -3
#   PHILIPS_B :   10
#
# PnL: -104.10
#
# -1.0200000000000102
# -2.3399999999999666
# Top level prices for PHILIPS_A: 96.50 :: 97.00
# Inserting ask for PHILIPS_A: 1 lot(s) at price 96.50.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:35:00.518714 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -4
#   PHILIPS_B :   10
#
# PnL: -106.60
#
# 2.3400000000000034
# -1.2999999999999887
# Top level prices for PHILIPS_A: 96.80 :: 97.00
# Inserting bid for PHILIPS_A: 1 lot(s) at price 97.00.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:35:30.553251 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -3
#   PHILIPS_B :   10
#
# PnL: -102.70
#
# 1.920000000000016
# 0.939999999999975
# Top level prices for PHILIPS_A: 97.00 :: 97.50
# Inserting bid for PHILIPS_A: 1 lot(s) at price 97.50.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:36:00.581459 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -2
#   PHILIPS_B :   10
#
# PnL: -98.50
#
# -2.17999999999999
# -2.5999999999999717
# Top level prices for PHILIPS_A: 97.10 :: 97.80
# Inserting ask for PHILIPS_A: 1 lot(s) at price 97.10.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:36:30.597351 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -3
#   PHILIPS_B :   10
#
# PnL: -99.20
#
# 2.4999999999999942
# -1.2600000000000022
# Top level prices for PHILIPS_A: 97.20 :: 97.80
# Inserting bid for PHILIPS_A: 1 lot(s) at price 97.80.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:37:00.642259 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -2
#   PHILIPS_B :   10
#
# PnL: -101.80
#
# -1.660000000000028
# -2.5999999999999943
# Top level prices for PHILIPS_A: 97.60 :: 98.00
# Inserting ask for PHILIPS_A: 1 lot(s) at price 97.60.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:37:30.683819 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -3
#   PHILIPS_B :   10
#
# PnL: -96.50
#
# 1.8
# -1.0200000000000018
# Top level prices for PHILIPS_A: 99.20 :: 99.80
# Inserting bid for PHILIPS_A: 1 lot(s) at price 99.80.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:38:00.722672 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -2
#   PHILIPS_B :   10
#
# PnL: -85.20
#
# -0.42000000000002446
# 3.59999999999998
# Top level prices for PHILIPS_A: 99.70 :: 99.90
# Inserting ask for PHILIPS_A: 1 lot(s) at price 99.70.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:38:30.767963 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -3
#   PHILIPS_B :   10
#
# PnL: -92.00
#
# 1.0400000000000147
# 0.24000000000001762
# Top level prices for PHILIPS_A: 99.70 :: 99.90
# Inserting bid for PHILIPS_A: 1 lot(s) at price 99.90.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:39:00.811730 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -2
#   PHILIPS_B :   10
#
# PnL: -82.60
#
# 1.6599999999999853
# 2.719999999999976
# Top level prices for PHILIPS_A: 99.40 :: 100.00
# Inserting bid for PHILIPS_A: 1 lot(s) at price 100.00.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:39:30.852766 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -1
#   PHILIPS_B :   10
#
# PnL: -80.70
#
# 2.2400000000000033
# 0.0
# Top level prices for PHILIPS_A: 100.20 :: 100.90
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:40:00.876263 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -1
#   PHILIPS_B :   10
#
# PnL: -87.00
#
# -1.0399999999999494
# -2.5399999999999636
# Top level prices for PHILIPS_A: 100.20 :: 100.60
# Inserting ask for PHILIPS_A: 1 lot(s) at price 100.20.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:40:30.923750 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -2
#   PHILIPS_B :   10
#
# PnL: -82.80
#
# -1.1599999999999853
# -2.780000000000038
# Top level prices for PHILIPS_A: 98.30 :: 98.90
# Inserting ask for PHILIPS_A: 1 lot(s) at price 98.30.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:41:00.965393 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -3
#   PHILIPS_B :   10
#
# PnL: -90.20
#
# 3.259999999999954
# 0.0
# Top level prices for PHILIPS_A: 98.30 :: 98.50
# Inserting bid for PHILIPS_A: 1 lot(s) at price 98.50.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:41:31.001088 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -2
#   PHILIPS_B :   10
#
# PnL: -95.40
#
# -2.0599999999999654
# -0.6999999999999631
# Top level prices for PHILIPS_A: 98.30 :: 98.90
# Inserting ask for PHILIPS_A: 1 lot(s) at price 98.30.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:42:01.029582 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -3
#   PHILIPS_B :   10
#
# PnL: -97.50
#
# -0.18000000000003807
# -0.820000000000013
# Top level prices for PHILIPS_A: 97.20 :: 97.80
# Inserting ask for PHILIPS_A: 1 lot(s) at price 97.20.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:42:31.077182 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -4
#   PHILIPS_B :   10
#
# PnL: -92.50
#
# -3.379999999999993
# -1.1200000000000159
# Top level prices for PHILIPS_B: 97.20 :: 98.60
# Not inserting 1 lot bid for PHILIPS_B to avoid position-limit breach.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:43:01.107653 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -4
#   PHILIPS_B :   10
#
# PnL: -99.70
#
# -1.7600000000000506
# -0.039999999999980676
# Top level prices for PHILIPS_B: 96.80 :: 97.10
# Not inserting 1 lot bid for PHILIPS_B to avoid position-limit breach.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:43:31.119533 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -4
#   PHILIPS_B :   10
#
# PnL: -99.70
#
# -3.4800000000000098
# -1.200000000000037
# Top level prices for PHILIPS_B: 96.50 :: 97.10
# Not inserting 1 lot bid for PHILIPS_B to avoid position-limit breach.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:44:01.126688 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -4
#   PHILIPS_B :   10
#
# PnL: -104.10
#
# -1.8599999999999597
# -3.2999999999999856
# Top level prices for PHILIPS_A: 93.70 :: 94.10
# Inserting ask for PHILIPS_A: 1 lot(s) at price 93.70.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:44:31.164007 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -5
#   PHILIPS_B :   10
#
# PnL: -112.50
#
# 2.720000000000039
# -2.0
# Top level prices for PHILIPS_A: 94.30 :: 94.90
# Inserting bid for PHILIPS_A: 1 lot(s) at price 94.90.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:45:01.210395 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -4
#   PHILIPS_B :   10
#
# PnL: -121.90
#
# -4.260000000000019
# -3.939999999999992
# Top level prices for PHILIPS_A: 93.40 :: 94.00
# Inserting ask for PHILIPS_A: 1 lot(s) at price 93.40.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:45:31.283273 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -5
#   PHILIPS_B :   10
#
# PnL: -123.00
#
# -1.279999999999987
# -2.019999999999996
# Top level prices for PHILIPS_A: 93.10 :: 93.70
# Inserting ask for PHILIPS_A: 1 lot(s) at price 93.10.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:46:01.322399 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -6
#   PHILIPS_B :   10
#
# PnL: -125.60
#
# 0.5399999999999722
# -0.9600000000000136
# Top level prices for PHILIPS_A: 93.30 :: 93.50
# Inserting bid for PHILIPS_A: 1 lot(s) at price 93.50.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:46:31.449798 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -5
#   PHILIPS_B :   10
#
# PnL: -124.90
#
# -1.5599999999999852
# 1.4399999999999864
# Top level prices for PHILIPS_A: 93.20 :: 93.50
# Inserting ask for PHILIPS_A: 1 lot(s) at price 93.20.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:47:01.479749 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -6
#   PHILIPS_B :   10
#
# PnL: -127.70
#
# -3.2200000000000073
# -0.2400000000000091
# Top level prices for PHILIPS_A: 92.70 :: 92.80
# Inserting ask for PHILIPS_A: 1 lot(s) at price 92.70.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:47:31.498198 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -7
#   PHILIPS_B :   10
#
# PnL: -125.20
#
# 1.6799999999999926
# 0.2400000000000233
# Top level prices for PHILIPS_A: 93.00 :: 93.60
# Inserting bid for PHILIPS_A: 1 lot(s) at price 93.60.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:48:01.541681 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -6
#   PHILIPS_B :   10
#
# PnL: -124.20
#
# -0.3599999999999966
# -1.039999999999995
# Top level prices for PHILIPS_A: 93.20 :: 93.90
# Inserting ask for PHILIPS_A: 1 lot(s) at price 93.20.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:48:31.601356 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -7
#   PHILIPS_B :   10
#
# PnL: -125.80
#
# 0.32000000000000456
# 0.0
# Top level prices for PHILIPS_A: 93.20 :: 93.40
# Inserting bid for PHILIPS_A: 1 lot(s) at price 93.40.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:49:01.641827 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -6
#   PHILIPS_B :   10
#
# PnL: -131.20
#
# -1.7200000000000073
# -1.4199999999999988
# Top level prices for PHILIPS_A: 92.40 :: 92.90
# Inserting ask for PHILIPS_A: 1 lot(s) at price 92.40.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:49:31.660511 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -7
#   PHILIPS_B :   10
#
# PnL: -132.40
#
# -1.7000000000000255
# -1.7199999999999904
# Top level prices for PHILIPS_B: 91.50 :: 92.20
# Not inserting 1 lot bid for PHILIPS_B to avoid position-limit breach.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:50:01.675359 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -7
#   PHILIPS_B :   10
#
# PnL: -133.30
#
# 1.6999999999999602
# 1.9200000000000272
# Top level prices for PHILIPS_A: 92.50 :: 92.70
# Inserting bid for PHILIPS_A: 1 lot(s) at price 92.70.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:50:31.736244 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -6
#   PHILIPS_B :   10
#
# PnL: -130.70
#
# -0.3799999999999869
# -0.5199999999999761
# Top level prices for PHILIPS_A: 92.00 :: 92.50
# Inserting ask for PHILIPS_A: 1 lot(s) at price 92.00.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:51:01.776803 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -7
#   PHILIPS_B :   10
#
# PnL: -137.10
#
# 4.8
# 0.0
# Top level prices for PHILIPS_A: 92.30 :: 92.60
# Inserting bid for PHILIPS_A: 1 lot(s) at price 92.60.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:51:31.823502 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -6
#   PHILIPS_B :   10
#
# PnL: -139.90
#
# 0.11999999999997328
# -1.9200000000000272
# Top level prices for PHILIPS_A: 92.10 :: 92.70
# Inserting bid for PHILIPS_A: 1 lot(s) at price 92.70.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:52:01.863572 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -5
#   PHILIPS_B :   10
#
# PnL: -134.40
#
# 0.26000000000002216
# 0.0
# Top level prices for PHILIPS_A: 92.80 :: 93.40
# Inserting bid for PHILIPS_A: 1 lot(s) at price 93.40.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:52:31.906774 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -4
#   PHILIPS_B :   10
#
# PnL: -131.80
#
# -1.379999999999987
# 0.29999999999998295
# Top level prices for PHILIPS_A: 92.60 :: 93.00
# Inserting ask for PHILIPS_A: 1 lot(s) at price 92.60.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:53:01.950706 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -5
#   PHILIPS_B :   10
#
# PnL: -128.70
#
# 2.8799999999999897
# -1.0799999999999528
# Top level prices for PHILIPS_A: 93.10 :: 93.70
# Inserting bid for PHILIPS_A: 1 lot(s) at price 93.70.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:53:32.027372 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -4
#   PHILIPS_B :   10
#
# PnL: -133.50
#
# -1.379999999999987
# -0.04000000000000341
# Top level prices for PHILIPS_B: 93.60 :: 94.20
# Not inserting 1 lot bid for PHILIPS_B to avoid position-limit breach.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:54:02.058668 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -4
#   PHILIPS_B :   10
#
# PnL: -127.90
#
# -1.039999999999992
# -1.0800000000000154
# Top level prices for PHILIPS_A: 92.20 :: 92.50
# Inserting ask for PHILIPS_A: 1 lot(s) at price 92.20.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:54:32.098188 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -5
#   PHILIPS_B :   10
#
# PnL: -133.70
#
# 0.39999999999998864
# -2.660000000000031
# Top level prices for PHILIPS_A: 91.80 :: 92.10
# Inserting bid for PHILIPS_A: 1 lot(s) at price 92.10.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:55:02.139409 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -4
#   PHILIPS_B :   10
#
# PnL: -139.80
#
# 3.1799999999999726
# -1.3000000000000114
# Top level prices for PHILIPS_A: 92.60 :: 93.00
# Inserting bid for PHILIPS_A: 1 lot(s) at price 93.00.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:55:32.185039 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -3
#   PHILIPS_B :   10
#
# PnL: -138.30
#
# -2.4599999999999596
# 0.9600000000000136
# Top level prices for PHILIPS_B: 92.00 :: 92.20
# Not inserting 1 lot bid for PHILIPS_B to avoid position-limit breach.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:56:02.192382 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -3
#   PHILIPS_B :   10
#
# PnL: -148.60
#
# -1.7999999999999603
# -5.159999999999977
# Top level prices for PHILIPS_A: 90.30 :: 90.60
# Inserting ask for PHILIPS_A: 1 lot(s) at price 90.30.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:56:32.234762 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -4
#   PHILIPS_B :   10
#
# PnL: -146.30
#
# 0.479999999999967
# 0.5000000000000397
# Top level prices for PHILIPS_A: 90.10 :: 90.60
# Inserting bid for PHILIPS_A: 1 lot(s) at price 90.60.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:57:02.255588 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -4
#   PHILIPS_B :   10
#
# PnL: -145.70
#
# 3.159999999999985
# 0.6000000000000199
# Top level prices for PHILIPS_A: 91.80 :: 92.10
# Inserting bid for PHILIPS_A: 1 lot(s) at price 92.10.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:57:32.301373 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -3
#   PHILIPS_B :   10
#
# PnL: -133.40
#
# -1.3399999999999976
# 0.6400000000000148
# Top level prices for PHILIPS_A: 92.10 :: 92.80
# Inserting ask for PHILIPS_A: 1 lot(s) at price 92.10.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:58:02.340380 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -4
#   PHILIPS_B :   10
#
# PnL: -140.30
#
# 2.2199999999999904
# 1.279999999999987
# Top level prices for PHILIPS_A: 92.70 :: 93.40
# Inserting bid for PHILIPS_A: 1 lot(s) at price 93.40.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:58:32.374468 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -3
#   PHILIPS_B :   10
#
# PnL: -142.10
#
# -1.5800000000000096
# 0.36000000000001364
# Top level prices for PHILIPS_A: 93.10 :: 93.50
# Inserting ask for PHILIPS_A: 1 lot(s) at price 93.10.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:59:02.415825 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -4
#   PHILIPS_B :   10
#
# PnL: -130.60
#
# 3.1199999999999735
# 2.400000000000034
# Top level prices for PHILIPS_A: 93.10 :: 93.50
# Inserting bid for PHILIPS_A: 1 lot(s) at price 93.50.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 12:59:32.458524 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -3
#   PHILIPS_B :   10
#
# PnL: -127.70
#
# 1.4400000000000461
# 0.6800000000000181
# Top level prices for PHILIPS_A: 92.80 :: 93.30
# Inserting bid for PHILIPS_A: 1 lot(s) at price 93.30.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 13:00:02.478026 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -2
#   PHILIPS_B :   10
#
# PnL: -127.60
#
# 0.959999999999954
# 0.6599999999999738
# Top level prices for PHILIPS_A: 93.00 :: 93.70
# Inserting bid for PHILIPS_A: 1 lot(s) at price 93.70.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 13:00:32.531259 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -1
#   PHILIPS_B :   10
#
# PnL: -132.60
#
# -0.2199999999999676
# -0.21999999999999886
# Top level prices for PHILIPS_B: 92.90 :: 93.50
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 13:01:02.562347 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -1
#   PHILIPS_B :   10
#
# PnL: -125.80
#
# 2.760000000000036
# 2.67999999999999
# Top level prices for PHILIPS_A: 94.50 :: 95.10
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 13:01:32.563421 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -1
#   PHILIPS_B :   10
#
# PnL: -122.20
#
# 0.19999999999999715
# 0.7600000000000108
# Top level prices for PHILIPS_A: 94.80 :: 95.40
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 13:02:02.589330 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -1
#   PHILIPS_B :   10
#
# PnL: -119.70
#
# 1.6200000000000045
# -0.6600000000000307
# Top level prices for PHILIPS_A: 95.90 :: 96.40
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 13:02:32.618057 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -1
#   PHILIPS_B :   10
#
# PnL: -120.80
#
# 0.3799999999999727
# 1.6200000000000017
# Top level prices for PHILIPS_A: 96.20 :: 96.50
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 13:03:02.648781 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -1
#   PHILIPS_B :   10
#
# PnL: -119.80
#
# -0.1799999999999983
# -2.3399999999999777
# Top level prices for PHILIPS_A: 95.90 :: 96.60
# Inserting ask for PHILIPS_A: 1 lot(s) at price 95.90.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 13:03:32.664889 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -2
#   PHILIPS_B :   10
#
# PnL: -114.60
#
# 7.180000000000012
# 1.9199999999999704
# Top level prices for PHILIPS_A: 96.90 :: 97.60
# Inserting bid for PHILIPS_A: 1 lot(s) at price 97.60.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 13:04:02.710794 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -1
#   PHILIPS_B :   10
#
# PnL: -105.00
#
# -2.7600000000000393
# 1.919999999999996
# Top level prices for PHILIPS_A: 96.30 :: 97.00
# Inserting ask for PHILIPS_A: 1 lot(s) at price 96.30.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 13:04:32.755737 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -2
#   PHILIPS_B :   10
#
# PnL: -102.50
#
# 5.179999999999973
# 1.3399999999999863
# Top level prices for PHILIPS_A: 97.30 :: 97.70
# Inserting bid for PHILIPS_A: 1 lot(s) at price 97.70.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 13:05:02.801334 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -1
#   PHILIPS_B :   10
#
# PnL: -100.50
#
# -2.759999999999974
# 0.9600000000000136
# Top level prices for PHILIPS_B: 97.00 :: 97.40
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 13:05:32.803099 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -1
#   PHILIPS_B :   10
#
# PnL: -100.90
#
# -0.9600000000000136
# 0.0
# Top level prices for PHILIPS_B: 97.00 :: 97.70
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 13:06:02.811539 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -1
#   PHILIPS_B :   10
#
# PnL: -107.30
#
# 0.3799999999999727
# -0.4600000000000392
# Top level prices for PHILIPS_A: 96.80 :: 97.00
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 13:06:32.817838 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -1
#   PHILIPS_B :   10
#
# PnL: -103.60
#
# 0.9600000000000023
# -0.580000000000021
# Top level prices for PHILIPS_A: 96.40 :: 97.80
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 13:07:02.842973 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -1
#   PHILIPS_B :   10
#
# PnL: -104.50
#
# 1.6200000000000245
# 0.0
# Top level prices for PHILIPS_A: 97.40 :: 98.10
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 13:07:32.856219 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -1
#   PHILIPS_B :   10
#
# PnL: -104.20
#
# -0.9599999999999455
# 0.0
# Top level prices for PHILIPS_A: 97.30 :: 97.60
# Inserting ask for PHILIPS_A: 1 lot(s) at price 97.30.
#
# Sleeping for 5 seconds.
#
# -----------------------------------------------------------------
# TRADE LOOP ITERATION ENTERED AT 2022-01-23 13:08:02.886163 UTC.
# -----------------------------------------------------------------
# Positions:
#   PHILIPS_A :   -2
#   PHILIPS_B :   10
#
# PnL: -104.30
#
# -0.6400000000000091
# -1.2599999999999767
# Top level prices for PHILIPS_A: 97.20 :: 97.60
# Inserting ask for PHILIPS_A: 1 lot(s) at price 97.20.
#
# Sleeping for 5 seconds.
